# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic_train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# I am going to replace the missng values in Cabin with 1 or 0
df["cabin_null"] = np.where(df["Cabin"].isnull(),1,0)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  cabin_null
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# ...

# %%
df["cabin_null"].mean()
# Out:
# 0.7710437710437711

# %%
# I am going to replace the missing values in Age with 1 or 0
df["age_null"] = np.where(df["Age"].isnull(),1,0)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  cabin_null  age_null
# 0      0         A/5 21171   7.2500   NaN        S           1         0
# 1      0          PC 17599  71.2833   C85        C           0         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1         0
# ...

# %%
df["age_null"].mean()
# Out:
# 0.19865319865319866

# %%
df.groupby(df["Survived"])["cabin_null"].mean()
# Out:
# Survived
# 0    0.876138
# 1    0.602339
# Name: cabin_null, dtype: float64

# %% [markdown]
# # Techniques to Handle missing values:
#
# ### 1. Mean Median Mode
# ### 2. Random sample imputation
# ### 3. Capturing NAN with a new feature
# ### 4. End of distribution imputation
# ### 5. Arbitrary imputation
# ### 6. Frequent categories imputation

# %% [markdown]
# # 1. when to apply Mean Median Mode replacement
# ### When we have MCAR
# ### We will replace NA values with mean/median/mode

# %%
df = pd.read_csv("titanic_train.csv",usecols=["Age","Fare","Survived"])
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean()
# Out:
# Survived    0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %%
# here we will replace the NA with median value in Age column
median_age = df.Age.median()
median_age
# Out:
# 28.0

# %%
def new_age(df,variable,median):
    df["New Age"] = df[variable].fillna(median)

# %%
new_age(df,"Age",median_age)
df.head(50)
# Out:
#     Survived   Age      Fare  New Age
# 0          0  22.0    7.2500     22.0
# 1          1  38.0   71.2833     38.0
# 2          1  26.0    7.9250     26.0
# 3          1  35.0   53.1000     35.0
# 4          0  35.0    8.0500     35.0
# 5          0   NaN    8.4583     28.0
# 6          0  54.0   51.8625     54.0
# 7          0   2.0   21.0750      2.0
# 8          1  27.0   11.1333     27.0
# 9          1  14.0   30.0708     14.0
# 10         1   4.0   16.7000      4.0
# 11         1  58.0   26.5500     58.0
# 12         0  20.0    8.0500     20.0
# 13         0  39.0   31.2750     39.0
# 14         0  14.0    7.8542     14.0
# 15         1  55.0   16.0000     55.0
# 16         0   2.0   29.1250      2.0
# 17         1   NaN   13.0000     28.0
# 18         0  31.0   18.0000     31.0
# 19         1   NaN    7.2250     28.0
# 20         0  35.0   26.0000     35.0
# 21         1  34.0   13.0000     34.0
# 22         1  15.0    8.0292     15.0
# 23         1  28.0   35.5000     28.0
# ...

# %%
df["New Age"].isnull().mean()
# Out:
# 0.0

# %%
print(df["Age"].std())
print(df["New Age"].std())
# Out:
# 14.526497332334044
# 13.019696550973194

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df["Age"].plot(kind="kde")
df["New Age"].plot(kind="kde",color="red")
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Advantages
# 1. Easy to implement
# 2. Faster way to compute
#
# ## Disadvantages
# 1. Change on the original variance
# 2. Impact on correlation
